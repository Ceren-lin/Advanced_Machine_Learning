# %%
import matplotlib.pyplot as plt

# 假设数据：NetA和NetB在每个epoch上的precision值

'''
o -- nol 没有使用小波包分解
x -- wpt 使用小波包分解
实线 -- lstm
虚线 -- gru

'''
plt.figure(figsize=(12, 8))

precisions_nol_lstm = [0.6867, 0.6835]
precisions_nol_lstm = [x * 100 for x in precisions_nol_lstm]
precisions_nol_lstm_self = [0.6192, 0.7891, 0.6628]
precisions_nol_lstm_self = [x * 100 for x in precisions_nol_lstm_self]
precisions_nol_lstm_cross = [0.6956, 0.6421, 0.7890]
precisions_nol_lstm_cross = [x * 100 for x in precisions_nol_lstm_cross]
precisions_wpt_lstm = [0.8792, 0.8915, 0.9709]
precisions_wpt_lstm = [x * 100 for x in precisions_wpt_lstm]
precisions_wpt_lstm_self = [0.8676, 0.9444, 0.9243]
precisions_wpt_lstm_self = [x * 100 for x in precisions_wpt_lstm_self]
precisions_wpt_lstm_cross = [0.6834, 0.8915, 0.9435]
precisions_wpt_lstm_cross = [x * 100 for x in precisions_wpt_lstm_cross]
precisions_nol_gru = [0.8197, 0.9361]
precisions_nol_gru = [x * 100 for x in precisions_nol_gru]
precisions_nol_gru_self = [0.4196,0.8653,0.9494]
precisions_nol_gru_self = [x * 100 for x in precisions_nol_gru_self]
precisions_nol_gru_cross = [0.4346,0.8998,0.9477]
precisions_nol_gru_cross = [x * 100 for x in precisions_nol_gru_cross]
precisions_nol_gru_selfcross = [0.3862,0.7953,0.9563]
precisions_nol_gru_selfcross = [x * 100 for x in precisions_nol_gru_selfcross]
precisions_wpt_gru = [0.8889, 0.8476, 0.9718]
precisions_wpt_gru = [x * 100 for x in precisions_wpt_gru]
precisions_wpt_gru_self = [0.9174, 0.9165, 0.9756]
precisions_wpt_gru_self = [x * 100 for x in precisions_wpt_gru_self]
precisions_wpt_gru_cross = [0.9176, 0.9301, 0.9679]
precisions_wpt_gru_cross = [x * 100 for x in precisions_wpt_gru_cross]
precisions_wpt_gru_selfcross = [0.8994, 0.9179, 0.9705]
precisions_wpt_gru_selfcross = [x * 100 for x in precisions_wpt_gru_selfcross]
precisions_nol_cnngru = [0.8457, 0.9386 ,0.95440]
precisions_nol_cnngru = [x * 100 for x in precisions_nol_cnngru]
precisions_wpt_cnngru = [0.9094, 0.9809]
precisions_wpt_cnngru = [x * 100 for x in precisions_wpt_cnngru]
precisions_nol_cnngru_att = [ 0.8457, 0.9386,0.95440]
precisions_nol_cnngru_att = [x * 100 for x in precisions_nol_cnngru_att]
precisions_wpt_cnngru_att = [0.9467, 0.9881]
precisions_wpt_cnngru_att = [x * 100 for x in precisions_wpt_cnngru_att]

epochs3 = [20,50,100]
epochs2 = [20,100]
epochslstm = [50,100]

# 绘制NetA的epoch-precision曲线
plt.plot(epochslstm, precisions_nol_lstm, marker='o', linestyle='-', color='blue', label='nol-lstm')

plt.plot(epochs3, precisions_nol_lstm_self, marker='o', linestyle='-', color='#87CEEB', label='nol-lstm-self')

plt.plot(epochs3, precisions_nol_lstm_cross, marker='o', linestyle='-', color='#4682B4', label='nol-lstm-cross')

plt.plot(epochs3, precisions_wpt_lstm, marker='x', linestyle='-', color='#0000CD', label='wpt-lstm')

plt.plot(epochs3, precisions_wpt_lstm_self, marker='x', linestyle='-', color='#1E90FF', label='wpt-lstm-self')

plt.plot(epochs3, precisions_wpt_lstm_cross, marker='x', linestyle='-', color='#6495ED', label='wpt-lstm-cross')

# 绘制NetB的epoch-precision曲线
plt.plot(epochs2, precisions_nol_gru, marker='o', linestyle='--', color='red', label='nol-gru')

plt.plot(epochs3, precisions_nol_gru_self, marker='o', linestyle='--', color='#F08080', label='nol-gru-self')

plt.plot(epochs3, precisions_nol_gru_cross, marker='o', linestyle='--', color='#CD5C5C', label='nol-gru-cross')

# plt.plot(epochs3, precisions_nol_gru_selfcross, marker='o', linestyle='--', color='#DC143C', label='nol-gru-selfcross')


plt.plot(epochs3, precisions_wpt_gru, marker='x', linestyle='--', color='#B22222', label='wpt-gru')

plt.plot(epochs3, precisions_wpt_gru_self, marker='x', linestyle='--', color='#8B0000', label='wpt-gru-self')

plt.plot(epochs3, precisions_wpt_gru_cross, marker='x', linestyle='--', color='#FA8072', label='wpt-gru-cross')

# plt.plot(epochs3, precisions_wpt_gru_selfcross, marker='x', linestyle='--', color='#FF6347', label='wpt-gru-selfcross')

### CNN-GRU
plt.plot(epochs3, precisions_nol_cnngru, marker='o', linestyle='-.', color='#F0E68C', label='nol-cnngru')

plt.plot(epochs2, precisions_wpt_cnngru, marker='x', linestyle='-.', color='#7FFFD4', label='wpt-cnngru')

plt.plot(epochs3, precisions_nol_cnngru_att, marker='o', linestyle='-.', color= '#00FF00', label='nol-cnngru-att')

plt.plot(epochs2, precisions_wpt_cnngru_att, marker='x', linestyle='-.', color='#FF00FF', label='wpt-cnngru-att')


# 添加图表标题、轴标签
plt.title('Epoch vs Precision for Different Networks')
plt.xlabel('Epoch')
plt.ylabel('Precision')

# 显示网格
plt.grid(True)

# 添加图例，并设置图例显示在图表外侧
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# 调整图表布局以防止图例被剪切
plt.tight_layout()

# Save the figure
plt.savefig('my_figure.png')


# 显示图表
plt.show()
